# %% [markdown]
# # Գրաֆիկները ստեղծում MatPlotLib-ով

# %% [markdown]
# **Matplotlib**-ը Python-ի գրադարան է, որը թույլ է տալիս ստեղծել գրաֆիկներ։ Այն լայնորեն օգտագործվում է տվյալների պատկերավորման համար։ Matplotlib-ը հիմնականում գործածվում է որպես 2D գրաֆիկական գործիք, բայց ունի նաև 3D պատկերներ ստեղծելու հնարավորություններ:
#
# Այն կարելի է են ներմուծել `plt` անվանմամբ հետևյալ հրահանգով։

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# MatPlotLib-ը ստեղծված է պատկերելու NumPy  զանգվածներ, այսինքն պետք է նաև ներմուծել Numpy-ն

# %%
import numpy as np

# %% [markdown]
# MatPlotLib-ով գրաֆիկներ ստեղծելու համար պետք է նրան տրամադրել պատկերվող տվյալները, թվային տեսքով։ Մեկ փոփոխականի Ֆունկցիային կորի տվյալները այդ ֆունկցիայի արժեքն է տարբեր կետերում։ Օրինակ ստեղծենք պարաբոլական ֆունկցիայի տվյալները.
# $$
# y = x^2
# $$

# %%
x = np.linspace(-10, 10, 21)
y = x**2

# %%
for i in range(0, 10):
    print('y(', x[i], ') = ', y[i])
# Out:
# y( -10.0 ) =  100.0
# y( -9.0 ) =  81.0
# y( -8.0 ) =  64.0
# y( -7.0 ) =  49.0
# y( -6.0 ) =  36.0
# y( -5.0 ) =  25.0
# y( -4.0 ) =  16.0
# y( -3.0 ) =  9.0
# y( -2.0 ) =  4.0
# y( -1.0 ) =  1.0

# %% [markdown]
# Այս տվյալները որպես գրաֆիկի `x` և `y` առանցքների արժեքներ օգտագործելու համար դրան տրվում են `plt.plot()` ֆունկցիային որպես արգումենտ։ Այլնուհետև կարող ենք գրաֆիկը պատկերել `plt.show()` ֆունկցիայի միջոցով:

# %% [markdown]
# ```python
# plt.plot(x, y)
# plt.show()
# ```

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# Ինպես տեսնում ենք, չնայած այն բանի, որ ֆունկցիային տրվել են դիսկրետ կետեր, այն պատկերում է հոծ գիծ։ Այս պահվածքը կարելի փոխել, սահմանելով կորի տեսքը որպես `plt.plot()` ֆունկցիայի երրորդ արգումենտ։

# %% [markdown]
# <pre style=""><code class="language-python">plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">,</span> <mark class="add"><span class="ͼ12">'.'</span></mark><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
def latex_arrow_props(color):
    return dict(
        arrowstyle='->,head_length=0.7,head_width=0.2',
        color=color,
        linewidth=1,
        shrinkA=2,
        shrinkB=8,
        connectionstyle="arc3,rad=0",
    )

# %%
plt.plot(x, y, '.')
plt.annotate('Կետավոր գիծ', (x[6], y[6]), (x[6]+2, y[6]+20), color="green", arrowprops=latex_arrow_props("green"))
plt.show()

# %% [markdown]
# <pre style=""><code class="language-python">plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">,</span> <mark class="add"><span class="ͼ12">'--'</span></mark><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
plt.plot(x, y, '--')
plt.annotate('Ընդհատվող գիծ', (x[6], y[6]), (x[6]+2, y[6]+20), color="green", arrowprops=latex_arrow_props("green"))
plt.show()

# %% [markdown]
# <pre style=""><code class="language-python">plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">,</span> <mark class="add"><span class="ͼ12">'-.'</span></mark><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
plt.plot(x, y, '-.')
plt.annotate('Կետգիծ', (x[6], y[6]), (x[6]+2, y[6]+20), color="green", arrowprops=latex_arrow_props("green"))
plt.show()

# %% [markdown]
# Առանցքների անվանումները տրվում են `plt.xlabel()` և `plt.ylabel()` ֆունկցիաներին։

# %% [markdown]
# <pre style=""><code class="language-python">plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">)</span>
# <mark class="add">plt<span class="ͼ19">.</span><span class="ͼz">xlabel</span><span class="ͼ19">(</span><span class="ͼ12">'x (My X axis)'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">ylabel</span><span class="ͼ19">(</span><span class="ͼ12">'$x^2$ (My Y axis)'</span><span class="ͼ19">)</span></mark>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
plt.plot(x, y)
plt.xlabel('x (My X axis)', color="green")
plt.ylabel('$x^2$ (My Y axis)', color="green")
plt.show()

# %% [markdown]
# Մաթեմատիկական արտահայտություններ պատկերելու համար՝ ինչպիսիք են օրինակ $x^2$ կամ $\frac{1}{2}$ պետք է դրան գրել [LaTeX](https://en.wikipedia.org/wiki/LaTeX) ֆորմատով `$` նշանների միջև։

# %% [markdown]
# Հնարավոր է նաև միևնույն գրաֆիկում պատկերել մեկից ավել կորեր։

# %% [markdown]
# <pre style=""><code class="language-python"><mark class="add">z <span class="ͼ10">=</span> np<span class="ͼ19">.</span><span class="ͼz">sin</span><span class="ͼ19">(</span>x<span class="ͼ19">)</span><span class="ͼ10">*</span><span class="ͼu">50</span> <span class="ͼ10">+</span> <span class="ͼu">50</span></mark>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">)</span>
# <mark class="add">plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> z<span class="ͼ19">)</span></mark>
# plt<span class="ͼ19">.</span><span class="ͼz">xlabel</span><span class="ͼ19">(</span><span class="ͼ12">'My X axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">ylabel</span><span class="ͼ19">(</span><span class="ͼ12">'My Y axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
z = np.sin(x)*50 + 50
plt.plot(x, y)
plt.plot(x, z)
plt.xlabel('My X axis')
plt.ylabel('My Y axis')
plt.annotate('Սինուսի Կորը', (x[6], z[6]), (x[6]+2, z[6]+10), color="green", arrowprops=latex_arrow_props("green"))
# Out:
# Text(-2.0, 97.84012476539641, 'Սինուսի Կորը')

# %% [markdown]
# Ինչպես տեսնում ենք, նոր կորերը ավտոմատ կերպով պատկերվում են տարբեր գույնով, առանց մեր կողմից դա սահմանելու, սակայն կորի գույնը նույնպես կարողենք փոխել։

# %% [markdown]
# <pre style=""><code class="language-python">z <span class="ͼ10">=</span> np<span class="ͼ19">.</span><span class="ͼz">sin</span><span class="ͼ19">(</span>x<span class="ͼ19">)</span><span class="ͼ10">*</span><span class="ͼu">50</span> <span class="ͼ10">+</span> <span class="ͼu">50</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">,</span> <mark class="add"><span class="ͼ12">'b-'</span></mark><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> z<span class="ͼ19">,</span> <mark class="add"><span class="ͼ12">'r--'</span></mark><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">xlabel</span><span class="ͼ19">(</span><span class="ͼ12">'My X axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">ylabel</span><span class="ͼ19">(</span><span class="ͼ12">'My Y axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
z = np.sin(x)*50 + 50
plt.plot(x, y, 'b-')
plt.plot(x, z, 'r--')
plt.xlabel('My X axis')
plt.ylabel('My Y axis')
plt.show()

# %% [markdown]
# **ՀԱՐՑ.** Ի՞նչու սինուսի կորը *սահուն* չէ, և ի՞նչպես ուղղել դա։

# %% [markdown]
# ```python
# x1 = np.linspace(-10, 10, 21)
# x2 = np.linspace(-10, 10, 201)
#
# plt.plot(x1, np.sin(x1)*50 + 50, 'r-')
# plt.plot(x2, np.sin(x2)*50 + 50, 'b--')
#
# plt.show()
# ```

# %%
x1 = np.linspace(-10, 10, 21) 
x2 = np.linspace(-10, 10, 201) 

plt.plot(x1, np.sin(x1)*50 + 50, 'r-')
plt.plot(x2, np.sin(x2)*50 + 50, 'b--')

plt.show()

# %% [markdown]
# ```python
# x = np.linspace(-10, 10, 201)
# y = x**2
# z = np.sin(x)*50 + 50
# ```

# %%
x = np.linspace(-10, 10, 201)
y = x**2
z = np.sin(x)*50 + 50

# %% [markdown]
# Նույն գրաֆիկում մեկից ավել կորեր պատկերելիս, հաճախ անհրաժեշտ է լինում տալ կոնկրետ կորի մասին ինֆորմացիա։ Այդ նպատակով օգտագործվում է `.plot()` ֆունկցիայի `label` արգումենտը: `label`-ը սահմանելուց հետո, պետք է կանչել `.legend()` ֆունկցիան՝ լեգենդը ցուցադրելու համար:

# %% [markdown]
# <pre style=""><code class="language-python">plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">,</span> <span class="ͼ12">'b-'</span><span class="ͼ19">,</span> <mark class="add">label<span class="ͼ10">=</span><span class="ͼ12">'$x^2$'</span></mark><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> z<span class="ͼ19">,</span> <span class="ͼ12">'r--'</span><span class="ͼ19">,</span> <mark class="add">label<span class="ͼ10">=</span><span class="ͼ12">'sin(x)'</span><span class="ͼ19"></mark>)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">xlabel</span><span class="ͼ19">(</span><span class="ͼ12">'My X axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">ylabel</span><span class="ͼ19">(</span><span class="ͼ12">'My Y axis'</span><span class="ͼ19">)</span>
# <mark class="add">plt<span class="ͼ19">.</span><span class="ͼz">legend</span><span class="ͼ19">(</span><span class="ͼ19">)</span></mark>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
plt.plot(x, y, 'b-', label='$x^2$')
plt.plot(x, z, 'r--', label='sin(x)')
plt.xlabel('My X axis')
plt.ylabel('My Y axis')
plt.annotate('Պիտակ', (8, 15), (6.5, 30), color="green", arrowprops=latex_arrow_props("green"))
plt.legend()
plt.show()

# %% [markdown]
# Գրաֆիկի վրա տեքստային մեկնաբանություններ ավելացնելու համար `plt.annotate()` ֆունկցիան է օգտագործվում: Այն թույլ է տալիս նշել գրաֆիկի կոնկրետ կետեր և դրանց վերաբերյալ տեղեկատվություն տրամադրել: Այն ընդունում է հետևյալ հիմնական արգումենտները.
#
# 1. `text`: Մեկնաբանության տեքստը:
# 2. `xy`: Կորի վրա կետի կոորդինատները, որի վերաբերյալ ուզում ենք թողնել մեկնաբանություն:
# 3. `xytext`: Մեկնաբանության տեքստի կոորդինատները (եթե տարբերվում է `xy`-ից):
# 4. `arrowprops`: Սլաքի հատկությունները, եթե ցանկանում ենք սլաք ավելացնել:
# 5. `fontsize`: Տեքստի չափը:
# 6. `color`: Տեքստի գույնը:

# %% [markdown]
# <pre style=""><code class="language-python">plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">,</span> <span class="ͼ12">'b-'</span><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'$x^2$'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> z<span class="ͼ19">,</span> <span class="ͼ12">'r--'</span><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'sin(x)'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">xlabel</span><span class="ͼ19">(</span><span class="ͼ12">'My X axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">ylabel</span><span class="ͼ19">(</span><span class="ͼ12">'My Y axis'</span><span class="ͼ19">)</span>
# <mark class="add">plt<span class="ͼ19">.</span><span class="ͼz">annotate</span><span class="ͼ19">(</span><span class="ͼ12">'min($x^2$)'</span><span class="ͼ19">,</span> <span class="ͼ19">(</span><span class="ͼu">0</span><span class="ͼ19">,</span> <span class="ͼu">0</span><span class="ͼ19">)</span><span class="ͼ19">,</span> <span class="ͼ19">(</span><span class="ͼu">0</span><span class="ͼ19">,</span> <span class="ͼu">20</span><span class="ͼ19">)</span><span class="ͼ19">,</span> color<span class="ͼ10">=</span><span class="ͼ12">"blue"</span><span class="ͼ19">,</span> fontsize<span class="ͼ10">=</span><span class="ͼu">12</span><span class="ͼ19">,</span> arrowprops<span class="ͼ10">=</span><span class="ͼ14">{</span><span class="ͼ12">"arrowstyle"</span>: <span class="ͼ12">"-&gt;"</span><span class="ͼ14">}</span><span class="ͼ19">)</span></mark>
# plt<span class="ͼ19">.</span><span class="ͼz">legend</span><span class="ͼ19">(</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
plt.plot(x, y, 'b-', label='$x^2$')
plt.plot(x, z, 'r--', label='sin(x)')
plt.xlabel('My X axis')
plt.ylabel('My Y axis')
plt.annotate('min($x^2$)', (0, 0), (0, 20), color="blue", fontsize=12, arrowprops={"arrowstyle": "->"})
plt.legend()
plt.show()

# %% [markdown]
# `.title()` ֆունկցիան օգտագործվում է MatPlotLib-ում գրաֆիկին վերնագիր ավելացնելու համար:
#
# <pre><code class="language-python"><mark class="add">plt<span class="ͼ19">.</span><span class="ͼz">title</span><span class="ͼ19">(</span><span class="ͼ12">'Example usages of MatPlotLib'</span><span class="ͼ19">)</span></mark>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">,</span> <span class="ͼ12">'b-'</span><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'$x^2$'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> z<span class="ͼ19">,</span> <span class="ͼ12">'r--'</span><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'sin(x)'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">xlabel</span><span class="ͼ19">(</span><span class="ͼ12">'My X axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">ylabel</span><span class="ͼ19">(</span><span class="ͼ12">'My Y axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">legend</span><span class="ͼ19">(</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
plt.title('Example usages of MatPlotLib', color="green")
plt.plot(x, y, 'b-', label='$x^2$')
plt.plot(x, z, 'r--', label='sin(x)')
plt.xlabel('My X axis')
plt.ylabel('My Y axis')
plt.legend()
plt.show()

# %% [markdown]
# Գրաֆիկի առանցքների վրա մանր սանդղակային նշումները (minor ticks) միացնելու համար օգտագործվում է `plt.minorticks_on()` ֆունկցիան: Այս ֆունկցիան սովորաբար օգտագործվում է `plt.tick_params()` հետ միասին՝ փոքր նշումների տեսքը կարգավորելու համար:

# %% [markdown]
# <pre style=""><code class="language-python">plt<span class="ͼ19">.</span><span class="ͼz">title</span><span class="ͼ19">(</span><span class="ͼ12">'Example usages of MatPlotLib'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">,</span> <span class="ͼ12">'b-'</span><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'$x^2$'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> z<span class="ͼ19">,</span> <span class="ͼ12">'r--'</span><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'sin(x)'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">xlabel</span><span class="ͼ19">(</span><span class="ͼ12">'My X axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">ylabel</span><span class="ͼ19">(</span><span class="ͼ12">'My Y axis'</span><span class="ͼ19">)</span>
# <mark class="add">plt<span class="ͼ19">.</span><span class="ͼz">minorticks_on</span><span class="ͼ19">(</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">tick_params</span><span class="ͼ19">(</span>axis<span class="ͼ10">=</span><span class="ͼ12">'y'</span><span class="ͼ19">,</span>which<span class="ͼ10">=</span><span class="ͼ12">'minor'</span><span class="ͼ19">,</span> color<span class="ͼ10">=</span><span class="ͼ12">'green'</span><span class="ͼ19">,</span> width<span class="ͼ10">=</span><span class="ͼu">2</span><span class="ͼ19">,</span> length<span class="ͼ10">=</span><span class="ͼu">10</span><span class="ͼ19">)</span></mark>
# plt<span class="ͼ19">.</span><span class="ͼz">legend</span><span class="ͼ19">(</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
plt.title('Example usages of MatPlotLib')
plt.plot(x, y, 'b-', label='$x^2$')
plt.plot(x, z, 'r--', label='sin(x)')
plt.xlabel('My X axis')
plt.ylabel('My Y axis')
plt.minorticks_on()
plt.tick_params(axis='y',which='minor', color='lightgreen', width=2, length=10)
plt.legend()
plt.show()

# %% [markdown]
# `markevery` արգումենտը օգտագործվում է գծի վրա տվյալների կետերը ցույց տվող նշանների (marker) հաճախականությունը կարգավորելու համար:

# %% [markdown]
# <pre style=""><code class="language-python">plt<span class="ͼ19">.</span><span class="ͼz">title</span><span class="ͼ19">(</span><span class="ͼ12">'Example usages of MatPlotLib'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">,</span> <span class="ͼ12">'b<mark class="add">o</mark>-'</span><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'$x^2$'</span><span class="ͼ19">,</span> <mark class="add">markevery<span class="ͼ10">=</span><span class="ͼu">6</span></mark><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> z<span class="ͼ19">,</span> <span class="ͼ12">'r<mark class="add">o</mark>--'</span><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'sin(x)'</span><span class="ͼ19">,</span> <mark class="add">markevery<span class="ͼ10">=</span><span class="ͼu">30</span></mark><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">xlabel</span><span class="ͼ19">(</span><span class="ͼ12">'My X axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">ylabel</span><span class="ͼ19">(</span><span class="ͼ12">'My Y axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">minorticks_on</span><span class="ͼ19">(</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">legend</span><span class="ͼ19">(</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
plt.title('Example usages of MatPlotLib')
plt.plot(x, y, 'bo-', label='$x^2$', markevery=6)
plt.plot(x, z, 'ro--', label='sin(x)', markevery=30)
plt.xlabel('My X axis')
plt.ylabel('My Y axis')
plt.minorticks_on()
plt.annotate('Խիտ է', (x[10], y[10]), (x[10]-0.4, y[10]+15), color="blue", arrowprops=latex_arrow_props("blue"))
plt.annotate('Նոսր է', (x[60], z[60]), (x[60]+2, z[60]-10), color="red", arrowprops=latex_arrow_props("red"))
plt.legend()
plt.show()

# %% [markdown]
# `'ro--'` արգումենտը կոչվում է «ձևավորող արժեք» (format string) և այն կարճ ձևով նկարագրում է կորի և մարկերների ոճը: Այս նոտացիան կարելի է բաժանել առանձին բաղադրիչների:
#
# 1. 'r' - գույնը (color)
# 2. 'o' - մարկերի ոճը (marker)
# 3. '--' - գծի ոճը (linestyle)
#
# Կարճ նոտացիայի բացատրություն.
#
# - Գույներ. 'r' նշանակում է կարմիր: Մյուս տարբերակներն են 'b' (կապույտ), 'g' (կանաչ), 'k' (սև), և այլն:
# - Մարկերներ. '^' նշանակում է եռանկյուն: Այլ տարբերակներ են 's' (քառակուսի), 'o' (շրջան), '*' (աստղանիշ), և այլն:
# - Գծի ոճեր. '--' նշանակում է ընդհատվող գիծ: Այլ տարբերակներ են '-' (հոծ գիծ), ':' (կետագիծ), '-.' (կետ-գծային), և այլն:
#
# Կարճ նոտացիայի տրամաբանությունը.
#
# 1. Հերթականությունը կարևոր չէ, բացառությամբ գույնի, որը պետք է լինի առաջինը:
# 2. Եթե որևէ տարր բացակայում է, օգտագործվում են լռելյայն (default) արժեքները:
#
# Կարճ նոտացիան հարմար է արագ գրաֆիկներ ստեղծելու համար, սակայն ավելի բարդ կամ հատուկ ոճավորման համար խորհուրդ է տրվում օգտագործել առանձին արգումենտներ, ինչպես ցույց տրվեց վերևում:
#
# Այս կարճ նոտացիան կարելի է փոխարինել նաև բացված տեսքով.

# %% [markdown]
# <pre style=""><code class="language-python">plt<span class="ͼ19">.</span><span class="ͼz">title</span><span class="ͼ19">(</span><span class="ͼ12">'Example usages of MatPlotLib'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">,</span> <span class="ͼ12">'bo-'</span><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'$x^2$'</span><span class="ͼ19">,</span> markevery<span class="ͼ10">=</span><span class="ͼu">6</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> z<span class="ͼ19">,</span> <mark class="add">color<span class="ͼ10">=</span><span class="ͼ12">'red'</span><span class="ͼ19">,</span> marker<span class="ͼ10">=</span><span class="ͼ12">'^'</span><span class="ͼ19">,</span> linestyle<span class="ͼ10">=</span><span class="ͼ12">'--'</span></mark><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'sin(x)'</span><span class="ͼ19">,</span> markevery<span class="ͼ10">=</span><span class="ͼu">30</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">xlabel</span><span class="ͼ19">(</span><span class="ͼ12">'My X axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">ylabel</span><span class="ͼ19">(</span><span class="ͼ12">'My Y axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">minorticks_on</span><span class="ͼ19">(</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">legend</span><span class="ͼ19">(</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
plt.title('Example usages of MatPlotLib')
plt.plot(x, y, 'bo-', label='$x^2$', markevery=6)
plt.plot(x, z, color='red', marker='^', linestyle='--', label='sin(x)', markevery=30)
plt.xlabel('My X axis')
plt.ylabel('My Y axis')
plt.annotate('Եռանկյուն', (x[60], z[60]), (x[60]+1, z[60]-10), color="red", arrowprops=latex_arrow_props("red"))
plt.minorticks_on()
plt.legend()
plt.show()

# %% [markdown]
# `.grid()` ֆունկցիան MatPlotLib-ում օգտագործվում է գրաֆիկի վրա ցանցային գծեր ավելացնելու համար: Այս ցանցը օգնում է ավելի հեշտությամբ կարդալ և մեկնաբանել գրաֆիկի արժեքները: Այն հատկապես օգտակար է, երբ անհրաժեշտ է ճշգրիտ գնահատել կետերի դիրքը կամ համեմատել տարբեր արժեքներ:

# %% [markdown]
# <pre style=""><code class="language-python">plt<span class="ͼ19">.</span><span class="ͼz">title</span><span class="ͼ19">(</span><span class="ͼ12">'Example usages of MatPlotLib'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> y<span class="ͼ19">,</span> <span class="ͼ12">'bo-'</span><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'$x^2$'</span><span class="ͼ19">,</span> markevery<span class="ͼ10">=</span><span class="ͼu">6</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">plot</span><span class="ͼ19">(</span>x<span class="ͼ19">,</span> z<span class="ͼ19">,</span> color<span class="ͼ10">=</span><span class="ͼ12">'red'</span><span class="ͼ19">,</span> marker<span class="ͼ10">=</span><span class="ͼ12">'^'</span><span class="ͼ19">,</span> linestyle<span class="ͼ10">=</span><span class="ͼ12">'--'</span><span class="ͼ19">,</span> label<span class="ͼ10">=</span><span class="ͼ12">'sin(x)'</span><span class="ͼ19">,</span> markevery<span class="ͼ10">=</span><span class="ͼu">30</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">xlabel</span><span class="ͼ19">(</span><span class="ͼ12">'My X axis'</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">ylabel</span><span class="ͼ19">(</span><span class="ͼ12">'My Y axis'</span><span class="ͼ19">)</span>
# <mark class="add">plt<span class="ͼ19">.</span><span class="ͼz">grid</span><span class="ͼ19">(</span>which<span class="ͼ10">=</span><span class="ͼ12">'both'</span><span class="ͼ19">,</span> linestyle<span class="ͼ10">=</span><span class="ͼ12">'--'</span><span class="ͼ19">,</span> color<span class="ͼ10">=</span><span class="ͼ12">'lightblue'</span><span class="ͼ19">,</span> alpha<span class="ͼ10">=</span><span class="ͼu">0.6</span><span class="ͼ19">)</span></mark>
# plt<span class="ͼ19">.</span><span class="ͼz">minorticks_on</span><span class="ͼ19">(</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">legend</span><span class="ͼ19">(</span><span class="ͼ19">)</span>
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
plt.title('Example usages of MatPlotLib')
plt.plot(x, y, 'bo-', label='$x^2$', markevery=6)
plt.plot(x, z, color='red', marker='^', linestyle='--', label='sin(x)', markevery=30)
plt.xlabel('My X axis')
plt.ylabel('My Y axis')
plt.grid(which='both', linestyle='--', color='lightblue', alpha=0.6)
plt.minorticks_on()
plt.legend()
plt.show()

# %% [markdown]
# Այս օրինակում `.grid()` ֆունկցիան ավելացնում է և՛ հիմնական (major), և՛ երկրորդական (minor) ցանցային գծեր (`which='both'`), որոնք ընդհատվող են (`linestyle='--'`), բաց կապույտ (`color='lightblue'`) և թափանցիկ (`alpha=0.7`): Այս կարգավորումները թույլ են տալիս ցանցը տեսանելի դարձնել՝ առանց շեղելու ուշադրությունը հիմնական տվյալներից:

# %% [markdown]
# ## Երկու և ավելի գրաֆիկների համատեղում մեկ պատկերում

# %% [markdown]
# Նախ ծանոթանանք MatPlotLib-ում առանցքների (axes) և պատկերների (figures) գաղափարի հետ:
#
# 1. Պատկեր (Figure):
#    - Պատկերը MatPlotLib-ում ամբողջական գրաֆիկական պատուհանն է:
#    - Այն կարող է պարունակել մեկ կամ մի քանի առանցքներ (axes):
#    - Ստեղծվում է `plt.figure()` ֆունկցիայով:
#
# 2. Առանցքներ (Axes):
#    - Առանցքները պատկերի մեջ գտնվող առանձին գրաֆիկական տարածքն են:
#    - Յուրաքանչյուր axis ունի իր x և y առանցքները:
#    - Մեկ պատկերում կարող են լինել մեկ կամ մի քանի axis:
#
# Մեկից ավել գրաֆիկներ ստեղծելու համար, պետք է մեկ պատկերում համատեղենք մի քանի առանցք։ Դա իրականացվում է ենթագծապատկերների (subplots) միջոցով.
#
# 3. Ենթագծապատկերներ (Subplots):
#    - Subplots-ը թույլ են տալիս մեկ պատկերի մեջ ստեղծել մի քանի առանցքներ:
#    - Դրանք օգտակար են մի քանի գրաֆիկներ համեմատելու կամ կապակցված տվյալներ ցուցադրելու համար:

# %% [markdown]
# Առանձնացնեք մեր գրաֆիկում պառաբոլայի և սինուսի գրաֆիկները առանձին առանցքների վրա.

# %% [markdown]
# ```python
# fig, axs = plt.subplots(1, 2, figsize=(12, 4))
#
# axs[0].set_title('Parabola')
# axs[0].plot(x, y, 'bo-', label='$x^2$', markevery=6)
# axs[0].set_xlabel('x')
# axs[0].set_ylabel('$x^2$')
# axs[0].minorticks_on()
# axs[0].legend()
#
# axs[1].set_title('Sinusoid')
# axs[1].plot(x, z, color='red', marker='^', linestyle='--', label='sin(x)', markevery=30)
# axs[1].set_xlabel('x')
# axs[1].set_ylabel('sin(x)')
# axs[1].minorticks_on()
# axs[1].legend()
#
# plt.show()
# ```

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

axs[0].set_title('Parabola')
axs[0].plot(x, y, 'bo-', label='$x^2$', markevery=6)
axs[0].set_xlabel('x')
axs[0].set_ylabel('$x^2$')
axs[0].minorticks_on()
axs[0].legend()

axs[1].set_title('Sinusoid')
axs[1].plot(x, z, color='red', marker='^', linestyle='--', label='sin(x)', markevery=30)
axs[1].set_xlabel('x')
axs[1].set_ylabel('sin(x)')
axs[1].minorticks_on()
axs[1].legend()

plt.show()

# %% [markdown]
# <pre style=""><code class="language-python">fig<span class="ͼ19">,</span> axs <span class="ͼ10">=</span> plt<span class="ͼ19">.</span><span class="ͼz">subplots</span><span class="ͼ19">(</span><span class="ͼu">3</span><span class="ͼ19">,</span> <span class="ͼu">3</span><span class="ͼ19">)</span>
#
# <mark style="background-color: #ddddff;">axs<span class="ͼ14">[</span><span class="ͼu">0</span><span class="ͼ19">,</span> <span class="ͼu">0</span><span class="ͼ14">]</span></mark><span class="ͼ19">.</span><span class="ͼz">set_facecolor</span><span class="ͼ19">(</span><span class="ͼ12">'#ddddff'</span><span class="ͼ19">)</span>
# <mark style="background-color: #ffffdd;">axs<span class="ͼ14">[</span><span class="ͼu">2</span><span class="ͼ19">,</span> <span class="ͼu">1</span><span class="ͼ14">]</span></mark><span class="ͼ19">.</span><span class="ͼz">set_facecolor</span><span class="ͼ19">(</span><span class="ͼ12">'#ffffdd'</span><span class="ͼ19">)</span>
#
# plt<span class="ͼ19">.</span><span class="ͼz">show</span><span class="ͼ19">(</span><span class="ͼ19">)</span></code></pre>

# %%
fig, axs = plt.subplots(3, 3)
axs[0, 0].set_facecolor('#ddddff')
axs[2, 1].set_facecolor('#ffffdd')

for ax in axs.flat:
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.tick_params(length=0)

plt.show()

# %% [markdown]
# ## Գրաֆիկների այլ տեսակներ

# %% [markdown]
# #### 1. Ցրման գրաֆիկ (Scatter plot):
#
# Օգտագործվում է երկու փոփոխականների միջև հարաբերությունը ցույց տալու համար: Յուրաքանչյուր կետ ներկայացնում է մեկ դիտարկում:

# %% [markdown]
# ```python
# N = 50
# x = np.random.rand(N)
# y = np.random.rand(N)
# colors = np.random.rand(N)
# area = (30 * np.random.rand(N))**2  # 0 to 15 point radii
#
# plt.scatter(x, y, s=area, c=colors, alpha=0.5)
# plt.show()
# ```

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# #### 2. Սյունակային գրաֆիկ (Bar plot):
#
# Ցույց է տալիս կատեգորիկ տվյալները ուղղահայաց կամ հորիզոնական սյունակների միջոցով:

# %% [markdown]
# ```python
# fruits = ['apple', 'blueberry', 'cherry', 'orange']
# counts = [40, 100, 30, 55]
# bar_labels = ['red', 'blue', '_red', 'orange']
# bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']
#
# plt.bar(fruits, counts, label=bar_labels, color=bar_colors)
#
# plt.ylabel('fruit supply')
# plt.title('Fruit supply by kind and color')
# plt.legend(title='Fruit color')
#
# plt.show()
# ```

# %%
fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

plt.bar(fruits, counts, label=bar_labels, color=bar_colors)

plt.ylabel('fruit supply')
plt.title('Fruit supply by kind and color')
plt.legend(title='Fruit color')

plt.show()

# %% [markdown]
# #### 3. Համահարթ գծերի գրաֆիկներ (contour plots)
#
# Համահարթ գծերի գրաֆիկները օգտագործվում են եռաչափ տվյալները երկչափ հարթության վրա ներկայացնելու համար: Դրանք ցույց են տալիս Z-ի հավասար արժեքներով կորեր X-Y հարթության մեջ: Սա նման է տեղագրական քարտեզի, որտեղ կորերը ցույց են տալիս հավասար բարձրությամբ կետեր:

# %% [markdown]
# ```python
# # Define a function to generate Z values
# def f(x, y):
#     return np.sin(np.sqrt(x**2 + y**2))
#
# # Generate X, Y values
# x = np.linspace(-5, 5, 50)
# y = np.linspace(-5, 5, 50)
# X, Y = np.meshgrid(x, y)
# Z = f(X, Y)
#
# # Create a filled contour plot
# fig, axs = plt.subplots(1, 2, figsize=(12, 4))
# cp = axs[0].contourf(X, Y, Z, levels=10, cmap='viridis')
# plt.colorbar(cp)  # Add color bar
#
# # Overlay contour lines on top of the filled contours
# contour_lines = axs[0].contour(X, Y, Z, levels=10, colors='black')
# axs[0].clabel(contour_lines, inline=True, fontsize=8)
#
# axs[0].set_title(r'Filled Contour plot of $\sin\left(\sqrt{x^2 + y^2}\right)$')
# axs[0].set_xlabel('X axis')
# axs[0].set_ylabel('Y axis')
#
# # 2D representation
# axs[1].plot(x, f(x, x), 'b')
# axs[1].set_title(r'Line plot of $\sin\left(\sqrt{x^2 + x^2}\right)$')
# axs[1].set_xlabel('Z axis')
# axs[1].set_ylabel('X axis')
#
# # Display the plot
# plt.show()
# ```

# %%
# Define a function to generate Z values
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Generate X, Y values
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# Create a filled contour plot
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
cp = axs[0].contourf(X, Y, Z, levels=10, cmap='viridis')
plt.colorbar(cp)  # Add color bar

# Overlay contour lines on top of the filled contours
contour_lines = axs[0].contour(X, Y, Z, levels=10, colors='black')
axs[0].clabel(contour_lines, inline=True, fontsize=8)

axs[0].set_title(r'Filled Contour plot of $\sin\left(\sqrt{x^2 + y^2}\right)$')
axs[0].set_xlabel('X axis')
axs[0].set_ylabel('Y axis')

# 2D representation
axs[1].plot(x, f(x, x), 'b')
axs[1].set_title(r'Line plot of $\sin\left(\sqrt{x^2 + x^2}\right)$')
axs[1].set_xlabel('Z axis')
axs[1].set_ylabel('X axis')

# Display the plot
plt.show()

# %% [markdown]
# #### 3. Հիստոգրամ (histogram)
#
# Հիստոգրամը տվյալների վիզուալիզացիայի գործիք է, որն օգտագործվում է թվային տվյալների բաշխումը ցույց տալու համար: MatPlotLib-ում `plt.hist()` ֆունկցիան օգտագործվում է հիստոգրամներ ստեղծելու համար: Այն աշխատում է հետևյալ կերպ.
#
# 1. Տվյալները բաժանվում են միջակայքերի (բիներ):
# 2. Յուրաքանչյուր միջակայքում հաշվվում է տվյալների քանակը:
# 3. Ստեղծվում են ուղղանկյուններ, որոնց բարձրությունը համապատասխանում է յուրաքանչյուր միջակայքի տվյալների քանակին:

# %% [markdown]
# ```python
# data = np.random.randn(1000)
# plt.hist(data, bins=30, color='blue', alpha=0.7, edgecolor='black')
#
# plt.title('Histogram of Normally Distributed Data')
# plt.xlabel('Value')
# plt.ylabel('Frequency')
#
# plt.show()
# ```

# %%
data = np.random.randn(1000)
plt.hist(data, bins=30, color='blue', alpha=0.7, edgecolor='black')

plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# #### 4. Errorbar
#
# Errorbar գծապատկերները ցույց են տալիս տվյալների անորոշությունը կամ փոփոխականությունը: Դրանք հատկապես օգտակար են գիտական տվյալների ներկայացման համար: Errorbar գծապատկերները օգտագործվում են, երբ կարևոր է ցույց տալ չափումների ճշգրտությունը կամ վիճակագրական տատանումները:

# %% [markdown]
# ```python
# x = np.array([1, 2, 3, 4, 5])
# y = np.array([1, 4, 9, 16, 25])
# yerr = np.array([0.5, 1, 0.7, 2, 1.2])
#
# plt.errorbar(x, y, yerr=yerr, fmt='o', capsize=5)
#
# plt.xlabel('X axis')
# plt.ylabel('Y axis')
# plt.title('Errorbar')
#
# plt.show()
# ```

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 4, 9, 16, 25])
yerr = np.array([0.5, 1, 0.7, 2, 1.2])

plt.errorbar(x, y, yerr=yerr, fmt='o', capsize=5)

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Errorbar')

plt.show()
